# %% [markdown]
# Final Project by Ike Pawsat, Luke Gearin, and Sam Forde

# %% [markdown]
# # Model 1: BERT Encoder with Roommate Dataset

# %% [markdown]
# Text-to-speech AI using BERT encoder with a CNN to recreate my roommates voice.

# %% [markdown]
# ## Imports and Data Processing

# %%
pip install transformers torchaudio librosa matplotlib
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: librosa in /usr/local/lib/python3.11/dist-packages (0.11.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: torch==2.6.0 in /usr/local/lib/python3.11/dist-packages (from torchaudio) (2.6.0+cu124)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch==2.6.0->torchaudio)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch==2.6.0->torchaudio)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch==2.6.0->torchaudio)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch==2.6.0->torchaudio)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch==2.6.0->torchaudio)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch==2.6.0->torchaudio)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch==2.6.0->torchaudio)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch==2.6.0->torchaudio)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch==2.6.0->torchaudio)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch==2.6.0->torchaudio)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch==2.6.0->torchaudio) (1.3.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.60.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.15.2)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa) (4.3.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.12.1->librosa) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.6.0->torchaudio) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 40.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 35.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 30.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.0 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.8 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 105.7 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
#import statements
from transformers import BertTokenizer, BertModel, DistilBertModel, DistilBertTokenizer
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import os
import string
import torchaudio

# %%
#google drive mounting and dataset
from google.colab import drive
drive.mount("/content/drive")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

dataset_path = "/content/drive/MyDrive/TTS_Dataset/Nick_Data/bee_movie_script.csv"  #update to our csv
wav_path = "/content/drive/MyDrive/TTS_Dataset/Nick_Data/recordings" #folder with wav files

#make dataframe
nick_data = pd.read_csv(dataset_path)
#skipped a line in recording so the first line becomes the column name, and I rename that column name to "lines"
nick_data.columns = ["lines"]
nick_data = nick_data[2:]
print(nick_data.head(3))

#removing punctuation now
nick_data["lines"] = nick_data["lines"].apply(lambda x: x.translate(str.maketrans("", "", string.punctuation)))
print(nick_data.head(3))

#cannot do gdown because .wav files, there is a 50 file limit
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Using device: cuda
#                                                lines
# 2  Yellow, black. Yellow, black. Yellow, black. Y...
# 3                             Ooh, black and yellow!
# 4                        Let's shake it up a little.
#                                                lines
# 2  Yellow black Yellow black Yellow black Yellow ...
# 3                               Ooh black and yellow
# 4                          Lets shake it up a little

# %%
#wav path defined above in wav_path
def make_wav_filename(index):
    return os.path.join(wav_path, f"{index:04d}.wav")

#add new wav_path for each file for the training
nick_data["wav_path"] = nick_data.index.map(make_wav_filename)
nick_data = nick_data[nick_data["wav_path"].apply(os.path.exists)]

#checks
print(nick_data[["lines", "wav_path"]].head(3))
print(nick_data.shape) #check shape
print(nick_data.loc[3, "wav_path"]) #check that 0 is 0000.wav because pandas truncates it
# Out:
#                                                lines  \
# 2  Yellow black Yellow black Yellow black Yellow ...
# 3                               Ooh black and yellow
# 4                          Lets shake it up a little
#
#                                             wav_path
# 2  /content/drive/MyDrive/TTS_Dataset/Nick_Data/r...
# 3  /content/drive/MyDrive/TTS_Dataset/Nick_Data/r...
# 4  /content/drive/MyDrive/TTS_Dataset/Nick_Data/r...
# (1285, 2)
# /content/drive/MyDrive/TTS_Dataset/Nick_Data/recordings/0003.wav

# %%
#typical 80 / 20 split
train_df, test_df = train_test_split(nick_data, test_size=0.2, random_state=42)

#sizes
print(f"Train size: {len(train_df)}")
print(f"Test size: {len(test_df)}")

#metadata format: wav_path|transcript
train_df["metadata"] = train_df.apply(lambda row: f"{row['wav_path']}|{row['lines']}", axis=1) #separated by |
test_df["metadata"] = test_df.apply(lambda row: f"{row['wav_path']}|{row['lines']}", axis=1)

#make csvs
train_df["metadata"].to_csv("train_metadata.csv", index=False, header=False)
test_df["metadata"].to_csv("test_metadata.csv", index=False, header=False)

print(train_df.head(3))
print(train_df.loc[1000, "metadata"]) #check if it combines lines with wav_path
# Out:
# Train size: 1028
# Test size: 257
#                                                   lines  \
# 970   And assuming youve done step correctly youre r...
# 748                                         This is Ken
# 1149                                                Yes
#
#                                                wav_path  \
# 970   /content/drive/MyDrive/TTS_Dataset/Nick_Data/r...
# 748   /content/drive/MyDrive/TTS_Dataset/Nick_Data/r...
# 1149  /content/drive/MyDrive/TTS_Dataset/Nick_Data/r...
#
#                                                metadata
# 970   /content/drive/MyDrive/TTS_Dataset/Nick_Data/r...
# 748   /content/drive/MyDrive/TTS_Dataset/Nick_Data/r...
# 1149  /content/drive/MyDrive/TTS_Dataset/Nick_Data/r...
# /content/drive/MyDrive/TTS_Dataset/Nick_Data/recordings/1000.wav|All the honey will finally belong to the bees

# %% [markdown]
# ## Model Setup

# %%
#use pretrained bert_model
#bert_model = BertModel.from_pretrained("bert-base-uncased")
bert_model = DistilBertModel.from_pretrained("distilbert-base-uncased") #smaller so trains faster

#tokenize data
#tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased") #smaller so trains faster

# %%
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

class TTSDataset(Dataset):
    def __init__(self, metadata_path, max_len=512):
        self.samples = []
        with open(metadata_path, "r") as f:
            for line in f:
                wav_path, text = line.strip().split("|")
                self.samples.append((wav_path, text))
        self.max_len = max_len
        self.mel_transform = torchaudio.transforms.MelSpectrogram(
            sample_rate=40000,
            n_fft=1024,
            hop_length=256,
            n_mels=80
        )

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        wav_path, text = self.samples[idx]

        # Load audio
        waveform, sr = torchaudio.load(wav_path)
        if sr != 40000:
            resampler = torchaudio.transforms.Resample(sr, 40000)
            waveform = resampler(waveform)

        mel = self.mel_transform(waveform).squeeze(0).transpose(0, 1)

        input_ids = tokenizer.encode(
            text,
            return_tensors="pt",
            padding="max_length",
            truncation=True,
            max_length=self.max_len
        ).squeeze(0)

        return input_ids, mel


def collate_fn(batch):
    input_ids, mels = zip(*batch)

    input_ids = torch.stack(input_ids)

    max_mel_len = max(mel.shape[0] for mel in mels)
    mel_dim = mels[0].shape[1]
    padded_mels = torch.zeros(len(mels), max_mel_len, mel_dim)

    for i, mel in enumerate(mels):
        padded_mels[i, :mel.shape[0], :] = mel

    return input_ids, padded_mels


train_dataset = TTSDataset("train_metadata.csv")
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, collate_fn=collate_fn, num_workers=4, pin_memory=True) #pin_memory speeds up GPU transfers


layers = [
    nn.Conv1d(in_channels=768, out_channels=512, kernel_size=3, padding=1),
    nn.ReLU(),
    nn.Dropout(0.2),
    nn.Conv1d(in_channels=512, out_channels=512, kernel_size=3, padding=1),
    nn.ReLU(),
    nn.Dropout(0.2),
    nn.Conv1d(in_channels=512, out_channels=512, kernel_size=3, padding=1),
    nn.ReLU(),
    nn.Dropout(0.2),
    nn.Conv1d(in_channels=512, out_channels=256, kernel_size=3, padding=1),
    nn.ReLU(),
    nn.Dropout(0.2),
    nn.Conv1d(in_channels=256, out_channels=80, kernel_size=1)
]

cnn = nn.Sequential(*layers).to(device)
optimizer = optim.Adam(cnn.parameters(), lr=1e-5)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %% [markdown]
# ## Model Training

# %%
import os
import torch
import torchaudio
import torchaudio.transforms as T

bert_model.eval()
bert_model.to(device)
loss_function = torch.nn.L1Loss()
num_epochs = 200 #honestly all you need since it is a small dataset

save_dir = "/content/drive/MyDrive/generated_wavs" #where to save .wavs
os.makedirs(save_dir, exist_ok=True)

# Griffin-Lim vocoder (basic mel -> waveform)
mel_to_audio = T.GriffinLim(n_fft=1024, n_iter=32)

for epoch in range(num_epochs):
    print(f"\nEpoch {epoch+1}/{num_epochs}")
    epoch_loss = 0.0
    total_batches = len(train_loader)

    for batch_idx, batch in enumerate(train_loader):
        input_ids, mel_targets = batch  #input_ids: [B, max_len], mel_targets: [B, T, 80]
        input_ids = input_ids.to(device)
        mel_targets = mel_targets.to(device)

        with torch.no_grad():
            bert_outputs = bert_model(input_ids)
            embeddings = bert_outputs.last_hidden_state  #[B, max_len, 768]

        x = embeddings.permute(0, 2, 1)  #[B, 768, max_len]
        out = cnn(x).permute(0, 2, 1)  #[B, T, 80]

        min_len = min(out.shape[1], mel_targets.shape[1])
        out = out[:, :min_len, :]
        mel_targets = mel_targets[:, :min_len, :]

        loss = loss_function(out, mel_targets)

        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        epoch_loss += loss.item()
        if (batch_idx + 1) % 10 == 0 or (batch_idx + 1) == total_batches:
            print(f"  Batch {batch_idx + 1}/{total_batches} | Loss: {loss.item():.4f}")

    avg_loss = epoch_loss / total_batches
    print(f"Epoch {epoch+1} complete. Avg Loss: {avg_loss:.4f}")

    mel_inv = T.InverseMelScale(n_stft=513, n_mels=80, sample_rate=40000)
    mel_to_audio = T.GriffinLim(n_fft=1024, n_iter=32)

    with torch.no_grad():
        sample_mel = mel_targets[0].cpu().T  #[80, T]
        spec = mel_inv(sample_mel)  #should be [513, T]

        #reconstruct waveform
        waveform = mel_to_audio(spec)
        waveform = waveform / waveform.abs().max()

        save_path = os.path.join(save_dir, f"epoch{epoch+1}_target.wav")
        torchaudio.save(save_path, waveform.unsqueeze(0), sample_rate=40000)
        print(f"Saved target audio sample to {save_path}")

save_model = os.path.join(save_dir, "model.pth")
torch.save(cnn.state_dict(), save_model)
print(f"Saved model to {save_model}")

#I attempted to use spectral loss but since the dataset is so small it did not help
# Out:
# Epoch 1/200
#   Batch 10/33 | Loss: 6.3880
#   Batch 20/33 | Loss: 4.8947
#   Batch 30/33 | Loss: 9.0659
#   Batch 33/33 | Loss: 4.5068
# Epoch 1 complete. Avg Loss: 7.4565
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch1_target.wav
#
# Epoch 2/200
#   Batch 10/33 | Loss: 9.3630
#   Batch 20/33 | Loss: 6.3160
#   Batch 30/33 | Loss: 6.0855
#   Batch 33/33 | Loss: 5.1039
# Epoch 2 complete. Avg Loss: 7.4723
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch2_target.wav
#
# Epoch 3/200
#   Batch 10/33 | Loss: 6.2270
#   Batch 20/33 | Loss: 8.8744
#   Batch 30/33 | Loss: 8.9875
#   Batch 33/33 | Loss: 5.4388
# Epoch 3 complete. Avg Loss: 7.4810
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch3_target.wav
#
# Epoch 4/200
#   Batch 10/33 | Loss: 5.6293
#   Batch 20/33 | Loss: 11.4215
#   Batch 30/33 | Loss: 7.2444
#   Batch 33/33 | Loss: 3.1441
# Epoch 4 complete. Avg Loss: 7.4200
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch4_target.wav
#
# Epoch 5/200
#   Batch 10/33 | Loss: 8.2059
#   Batch 20/33 | Loss: 5.2209
#   Batch 30/33 | Loss: 7.2055
#   Batch 33/33 | Loss: 9.8754
# Epoch 5 complete. Avg Loss: 7.5985
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch5_target.wav
#
# Epoch 6/200
#   Batch 10/33 | Loss: 8.8615
#   Batch 20/33 | Loss: 8.3414
#   Batch 30/33 | Loss: 6.1238
#   Batch 33/33 | Loss: 9.5615
# Epoch 6 complete. Avg Loss: 7.6040
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch6_target.wav
#
# Epoch 7/200
#   Batch 10/33 | Loss: 6.6841
#   Batch 20/33 | Loss: 6.3953
#   Batch 30/33 | Loss: 7.9727
#   Batch 33/33 | Loss: 8.2394
# Epoch 7 complete. Avg Loss: 7.5548
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch7_target.wav
#
# Epoch 8/200
#   Batch 10/33 | Loss: 10.8657
#   Batch 20/33 | Loss: 5.0488
#   Batch 30/33 | Loss: 5.8164
#   Batch 33/33 | Loss: 4.0200
# Epoch 8 complete. Avg Loss: 7.4449
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch8_target.wav
#
# Epoch 9/200
#   Batch 10/33 | Loss: 8.0455
#   Batch 20/33 | Loss: 4.1650
#   Batch 30/33 | Loss: 8.1210
#   Batch 33/33 | Loss: 6.1229
# Epoch 9 complete. Avg Loss: 7.4984
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch9_target.wav
#
# Epoch 10/200
#   Batch 10/33 | Loss: 7.1793
#   Batch 20/33 | Loss: 6.2720
#   Batch 30/33 | Loss: 9.7279
#   Batch 33/33 | Loss: 6.5049
# Epoch 10 complete. Avg Loss: 7.5157
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch10_target.wav
#
# Epoch 11/200
#   Batch 10/33 | Loss: 8.5053
#   Batch 20/33 | Loss: 8.0208
#   Batch 30/33 | Loss: 6.6953
#   Batch 33/33 | Loss: 13.8365
# Epoch 11 complete. Avg Loss: 7.7030
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch11_target.wav
#
# Epoch 12/200
#   Batch 10/33 | Loss: 7.0374
#   Batch 20/33 | Loss: 7.9590
#   Batch 30/33 | Loss: 7.9261
#   Batch 33/33 | Loss: 3.1528
# Epoch 12 complete. Avg Loss: 7.4194
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch12_target.wav
#
# Epoch 13/200
#   Batch 10/33 | Loss: 6.1027
#   Batch 20/33 | Loss: 7.9748
#   Batch 30/33 | Loss: 7.1215
#   Batch 33/33 | Loss: 8.8227
# Epoch 13 complete. Avg Loss: 7.5748
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch13_target.wav
#
# Epoch 14/200
#   Batch 10/33 | Loss: 6.6422
#   Batch 20/33 | Loss: 5.3436
#   Batch 30/33 | Loss: 8.2115
#   Batch 33/33 | Loss: 8.2307
# Epoch 14 complete. Avg Loss: 7.5538
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch14_target.wav
#
# Epoch 15/200
#   Batch 10/33 | Loss: 9.0341
#   Batch 20/33 | Loss: 16.1158
#   Batch 30/33 | Loss: 8.8997
#   Batch 33/33 | Loss: 6.0788
# Epoch 15 complete. Avg Loss: 7.4966
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch15_target.wav
#
# Epoch 16/200
#   Batch 10/33 | Loss: 7.0749
#   Batch 20/33 | Loss: 11.0011
#   Batch 30/33 | Loss: 3.9988
#   Batch 33/33 | Loss: 6.7933
# Epoch 16 complete. Avg Loss: 7.5253
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch16_target.wav
#
# Epoch 17/200
#   Batch 10/33 | Loss: 9.9053
#   Batch 20/33 | Loss: 7.1789
#   Batch 30/33 | Loss: 8.3869
#   Batch 33/33 | Loss: 7.8881
# Epoch 17 complete. Avg Loss: 7.5445
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch17_target.wav
#
# Epoch 18/200
#   Batch 10/33 | Loss: 7.9920
#   Batch 20/33 | Loss: 8.0250
#   Batch 30/33 | Loss: 5.9963
#   Batch 33/33 | Loss: 3.7588
# Epoch 18 complete. Avg Loss: 7.4349
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch18_target.wav
#
# Epoch 19/200
#   Batch 10/33 | Loss: 10.0931
#   Batch 20/33 | Loss: 8.5099
#   Batch 30/33 | Loss: 5.4626
#   Batch 33/33 | Loss: 9.2367
# Epoch 19 complete. Avg Loss: 7.5801
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch19_target.wav
#
# Epoch 20/200
#   Batch 10/33 | Loss: 7.2581
#   Batch 20/33 | Loss: 7.4324
#   Batch 30/33 | Loss: 8.2302
#   Batch 33/33 | Loss: 2.8532
# Epoch 20 complete. Avg Loss: 7.4107
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch20_target.wav
#
# Epoch 21/200
#   Batch 10/33 | Loss: 6.8823
#   Batch 20/33 | Loss: 11.0424
#   Batch 30/33 | Loss: 9.3603
#   Batch 33/33 | Loss: 7.1063
# Epoch 21 complete. Avg Loss: 7.5233
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch21_target.wav
#
# Epoch 22/200
#   Batch 10/33 | Loss: 6.6749
#   Batch 20/33 | Loss: 6.8525
#   Batch 30/33 | Loss: 6.5492
#   Batch 33/33 | Loss: 3.3649
# Epoch 22 complete. Avg Loss: 7.4243
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch22_target.wav
#
# Epoch 23/200
#   Batch 10/33 | Loss: 8.0772
#   Batch 20/33 | Loss: 16.0491
#   Batch 30/33 | Loss: 7.8706
#   Batch 33/33 | Loss: 3.0047
# Epoch 23 complete. Avg Loss: 7.4148
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch23_target.wav
#
# Epoch 24/200
#   Batch 10/33 | Loss: 7.1429
#   Batch 20/33 | Loss: 7.9341
#   Batch 30/33 | Loss: 7.0562
#   Batch 33/33 | Loss: 8.3247
# Epoch 24 complete. Avg Loss: 7.5564
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch24_target.wav
#
# Epoch 25/200
#   Batch 10/33 | Loss: 7.7250
#   Batch 20/33 | Loss: 7.1378
#   Batch 30/33 | Loss: 5.8693
#   Batch 33/33 | Loss: 8.3353
# Epoch 25 complete. Avg Loss: 7.5657
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch25_target.wav
#
# Epoch 26/200
#   Batch 10/33 | Loss: 9.6101
#   Batch 20/33 | Loss: 6.6410
#   Batch 30/33 | Loss: 12.0305
#   Batch 33/33 | Loss: 9.0071
# Epoch 26 complete. Avg Loss: 7.5812
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch26_target.wav
#
# Epoch 27/200
#   Batch 10/33 | Loss: 7.9208
#   Batch 20/33 | Loss: 7.0137
#   Batch 30/33 | Loss: 8.1055
#   Batch 33/33 | Loss: 4.7131
# Epoch 27 complete. Avg Loss: 7.4596
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch27_target.wav
#
# Epoch 28/200
#   Batch 10/33 | Loss: 10.8873
#   Batch 20/33 | Loss: 11.7471
#   Batch 30/33 | Loss: 6.6733
#   Batch 33/33 | Loss: 3.3285
# Epoch 28 complete. Avg Loss: 7.4229
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch28_target.wav
#
# Epoch 29/200
#   Batch 10/33 | Loss: 5.5514
#   Batch 20/33 | Loss: 9.6763
#   Batch 30/33 | Loss: 5.7551
#   Batch 33/33 | Loss: 18.2022
# Epoch 29 complete. Avg Loss: 7.8172
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch29_target.wav
#
# Epoch 30/200
#   Batch 10/33 | Loss: 7.2811
#   Batch 20/33 | Loss: 6.6115
#   Batch 30/33 | Loss: 7.0420
#   Batch 33/33 | Loss: 4.5788
# Epoch 30 complete. Avg Loss: 7.4559
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch30_target.wav
#
# Epoch 31/200
#   Batch 10/33 | Loss: 8.8812
#   Batch 20/33 | Loss: 7.6443
#   Batch 30/33 | Loss: 7.9264
#   Batch 33/33 | Loss: 4.6957
# Epoch 31 complete. Avg Loss: 7.4590
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch31_target.wav
#
# Epoch 32/200
#   Batch 10/33 | Loss: 5.2509
#   Batch 20/33 | Loss: 13.5116
#   Batch 30/33 | Loss: 7.2556
#   Batch 33/33 | Loss: 5.1413
# Epoch 32 complete. Avg Loss: 7.4708
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch32_target.wav
#
# Epoch 33/200
#   Batch 10/33 | Loss: 6.9499
#   Batch 20/33 | Loss: 5.6054
#   Batch 30/33 | Loss: 9.6806
#   Batch 33/33 | Loss: 7.7064
# Epoch 33 complete. Avg Loss: 7.5388
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch33_target.wav
#
# Epoch 34/200
#   Batch 10/33 | Loss: 8.1769
#   Batch 20/33 | Loss: 6.4022
#   Batch 30/33 | Loss: 7.2170
#   Batch 33/33 | Loss: 15.6592
# Epoch 34 complete. Avg Loss: 7.7495
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch34_target.wav
#
# Epoch 35/200
#   Batch 10/33 | Loss: 8.1552
#   Batch 20/33 | Loss: 10.1758
#   Batch 30/33 | Loss: 6.5656
#   Batch 33/33 | Loss: 5.2443
# Epoch 35 complete. Avg Loss: 7.4732
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch35_target.wav
#
# Epoch 36/200
#   Batch 10/33 | Loss: 15.2389
#   Batch 20/33 | Loss: 7.8681
#   Batch 30/33 | Loss: 7.1488
#   Batch 33/33 | Loss: 5.1577
# Epoch 36 complete. Avg Loss: 7.4709
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch36_target.wav
#
# Epoch 37/200
#   Batch 10/33 | Loss: 11.0905
#   Batch 20/33 | Loss: 6.5286
#   Batch 30/33 | Loss: 6.5976
#   Batch 33/33 | Loss: 5.7992
# Epoch 37 complete. Avg Loss: 7.4882
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch37_target.wav
#
# Epoch 38/200
#   Batch 10/33 | Loss: 6.6842
#   Batch 20/33 | Loss: 7.9656
#   Batch 30/33 | Loss: 10.9478
#   Batch 33/33 | Loss: 5.7563
# Epoch 38 complete. Avg Loss: 7.4867
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch38_target.wav
#
# Epoch 39/200
#   Batch 10/33 | Loss: 6.4204
#   Batch 20/33 | Loss: 8.2245
#   Batch 30/33 | Loss: 7.7746
#   Batch 33/33 | Loss: 7.9355
# Epoch 39 complete. Avg Loss: 7.5447
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch39_target.wav
#
# Epoch 40/200
#   Batch 10/33 | Loss: 6.3939
#   Batch 20/33 | Loss: 6.8550
#   Batch 30/33 | Loss: 6.7710
#   Batch 33/33 | Loss: 7.5312
# Epoch 40 complete. Avg Loss: 7.5337
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch40_target.wav
#
# Epoch 41/200
#   Batch 10/33 | Loss: 6.8833
#   Batch 20/33 | Loss: 4.4533
#   Batch 30/33 | Loss: 6.4662
#   Batch 33/33 | Loss: 20.8831
# Epoch 41 complete. Avg Loss: 7.8877
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch41_target.wav
#
# Epoch 42/200
#   Batch 10/33 | Loss: 7.3836
#   Batch 20/33 | Loss: 9.1851
#   Batch 30/33 | Loss: 6.4305
#   Batch 33/33 | Loss: 11.0726
# Epoch 42 complete. Avg Loss: 7.6335
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch42_target.wav
#
# Epoch 43/200
#   Batch 10/33 | Loss: 9.2210
#   Batch 20/33 | Loss: 7.4560
#   Batch 30/33 | Loss: 6.7982
#   Batch 33/33 | Loss: 2.4146
# Epoch 43 complete. Avg Loss: 7.3978
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch43_target.wav
#
# Epoch 44/200
#   Batch 10/33 | Loss: 5.8395
#   Batch 20/33 | Loss: 6.6579
#   Batch 30/33 | Loss: 8.7372
#   Batch 33/33 | Loss: 7.9440
# Epoch 44 complete. Avg Loss: 7.5451
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch44_target.wav
#
# Epoch 45/200
#   Batch 10/33 | Loss: 9.5259
#   Batch 20/33 | Loss: 6.6605
#   Batch 30/33 | Loss: 6.4572
#   Batch 33/33 | Loss: 27.3075
# Epoch 45 complete. Avg Loss: 8.0896
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch45_target.wav
#
# Epoch 46/200
#   Batch 10/33 | Loss: 15.5497
#   Batch 20/33 | Loss: 8.4507
#   Batch 30/33 | Loss: 5.1490
#   Batch 33/33 | Loss: 12.1005
# Epoch 46 complete. Avg Loss: 7.6547
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch46_target.wav
#
# Epoch 47/200
#   Batch 10/33 | Loss: 4.8496
#   Batch 20/33 | Loss: 9.5223
#   Batch 30/33 | Loss: 5.6249
#   Batch 33/33 | Loss: 9.1362
# Epoch 47 complete. Avg Loss: 7.5760
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch47_target.wav
#
# Epoch 48/200
#   Batch 10/33 | Loss: 9.4289
#   Batch 20/33 | Loss: 8.3451
#   Batch 30/33 | Loss: 4.7173
#   Batch 33/33 | Loss: 5.4660
# Epoch 48 complete. Avg Loss: 7.4789
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch48_target.wav
#
# Epoch 49/200
#   Batch 10/33 | Loss: 6.3580
#   Batch 20/33 | Loss: 12.3114
#   Batch 30/33 | Loss: 12.6044
#   Batch 33/33 | Loss: 11.5538
# Epoch 49 complete. Avg Loss: 7.6400
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch49_target.wav
#
# Epoch 50/200
#   Batch 10/33 | Loss: 5.1672
#   Batch 20/33 | Loss: 11.4828
#   Batch 30/33 | Loss: 12.2724
#   Batch 33/33 | Loss: 3.3840
# Epoch 50 complete. Avg Loss: 7.4234
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch50_target.wav
#
# Epoch 51/200
#   Batch 10/33 | Loss: 6.5723
#   Batch 20/33 | Loss: 7.7152
#   Batch 30/33 | Loss: 8.6972
#   Batch 33/33 | Loss: 3.0311
# Epoch 51 complete. Avg Loss: 7.4141
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch51_target.wav
#
# Epoch 52/200
#   Batch 10/33 | Loss: 9.8312
#   Batch 20/33 | Loss: 6.1674
#   Batch 30/33 | Loss: 8.1281
#   Batch 33/33 | Loss: 15.3005
# Epoch 52 complete. Avg Loss: 7.7395
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch52_target.wav
#
# Epoch 53/200
#   Batch 10/33 | Loss: 6.0756
#   Batch 20/33 | Loss: 8.0920
#   Batch 30/33 | Loss: 6.3331
#   Batch 33/33 | Loss: 9.0852
# Epoch 53 complete. Avg Loss: 7.5746
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch53_target.wav
#
# Epoch 54/200
#   Batch 10/33 | Loss: 17.2218
#   Batch 20/33 | Loss: 4.9480
#   Batch 30/33 | Loss: 7.3731
#   Batch 33/33 | Loss: 3.8612
# Epoch 54 complete. Avg Loss: 7.4408
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch54_target.wav
#
# Epoch 55/200
#   Batch 10/33 | Loss: 7.1987
#   Batch 20/33 | Loss: 5.8178
#   Batch 30/33 | Loss: 8.4568
#   Batch 33/33 | Loss: 5.6888
# Epoch 55 complete. Avg Loss: 7.4842
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch55_target.wav
#
# Epoch 56/200
#   Batch 10/33 | Loss: 5.8391
#   Batch 20/33 | Loss: 8.7844
#   Batch 30/33 | Loss: 9.2604
#   Batch 33/33 | Loss: 4.9345
# Epoch 56 complete. Avg Loss: 7.4646
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch56_target.wav
#
# Epoch 57/200
#   Batch 10/33 | Loss: 8.4366
#   Batch 20/33 | Loss: 5.0258
#   Batch 30/33 | Loss: 6.5540
#   Batch 33/33 | Loss: 6.5735
# Epoch 57 complete. Avg Loss: 7.5080
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch57_target.wav
#
# Epoch 58/200
#   Batch 10/33 | Loss: 8.9982
#   Batch 20/33 | Loss: 7.8274
#   Batch 30/33 | Loss: 5.8254
#   Batch 33/33 | Loss: 30.4122
# Epoch 58 complete. Avg Loss: 8.1396
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch58_target.wav
#
# Epoch 59/200
#   Batch 10/33 | Loss: 6.8063
#   Batch 20/33 | Loss: 7.5628
#   Batch 30/33 | Loss: 7.1799
#   Batch 33/33 | Loss: 8.0900
# Epoch 59 complete. Avg Loss: 7.5478
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch59_target.wav
#
# Epoch 60/200
#   Batch 10/33 | Loss: 7.0488
#   Batch 20/33 | Loss: 5.3403
#   Batch 30/33 | Loss: 5.1074
#   Batch 33/33 | Loss: 5.7390
# Epoch 60 complete. Avg Loss: 7.4855
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch60_target.wav
#
# Epoch 61/200
#   Batch 10/33 | Loss: 8.6997
#   Batch 20/33 | Loss: 6.7350
#   Batch 30/33 | Loss: 4.5557
#   Batch 33/33 | Loss: 4.7635
# Epoch 61 complete. Avg Loss: 7.4596
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch61_target.wav
#
# Epoch 62/200
#   Batch 10/33 | Loss: 5.5169
#   Batch 20/33 | Loss: 6.6121
#   Batch 30/33 | Loss: 8.9204
#   Batch 33/33 | Loss: 6.0588
# Epoch 62 complete. Avg Loss: 7.4943
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch62_target.wav
#
# Epoch 63/200
#   Batch 10/33 | Loss: 10.4266
#   Batch 20/33 | Loss: 4.8786
#   Batch 30/33 | Loss: 6.3670
#   Batch 33/33 | Loss: 7.3352
# Epoch 63 complete. Avg Loss: 7.5388
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch63_target.wav
#
# Epoch 64/200
#   Batch 10/33 | Loss: 9.3671
#   Batch 20/33 | Loss: 7.3123
#   Batch 30/33 | Loss: 6.8031
#   Batch 33/33 | Loss: 4.8880
# Epoch 64 complete. Avg Loss: 7.4629
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch64_target.wav
#
# Epoch 65/200
#   Batch 10/33 | Loss: 8.4965
#   Batch 20/33 | Loss: 10.0683
#   Batch 30/33 | Loss: 5.9319
#   Batch 33/33 | Loss: 2.8031
# Epoch 65 complete. Avg Loss: 7.4079
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch65_target.wav
#
# Epoch 66/200
#   Batch 10/33 | Loss: 9.7454
#   Batch 20/33 | Loss: 6.8753
#   Batch 30/33 | Loss: 13.2379
#   Batch 33/33 | Loss: 6.6680
# Epoch 66 complete. Avg Loss: 7.5109
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch66_target.wav
#
# Epoch 67/200
#   Batch 10/33 | Loss: 5.0729
#   Batch 20/33 | Loss: 8.5688
#   Batch 30/33 | Loss: 7.4343
#   Batch 33/33 | Loss: 6.5829
# Epoch 67 complete. Avg Loss: 7.5076
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch67_target.wav
#
# Epoch 68/200
#   Batch 10/33 | Loss: 6.3691
#   Batch 20/33 | Loss: 9.6771
#   Batch 30/33 | Loss: 6.7732
#   Batch 33/33 | Loss: 8.0324
# Epoch 68 complete. Avg Loss: 7.5484
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch68_target.wav
#
# Epoch 69/200
#   Batch 10/33 | Loss: 5.2394
#   Batch 20/33 | Loss: 8.7627
#   Batch 30/33 | Loss: 5.4209
#   Batch 33/33 | Loss: 2.6428
# Epoch 69 complete. Avg Loss: 7.4071
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch69_target.wav
#
# Epoch 70/200
#   Batch 10/33 | Loss: 5.5204
#   Batch 20/33 | Loss: 7.9131
#   Batch 30/33 | Loss: 6.9806
#   Batch 33/33 | Loss: 4.8868
# Epoch 70 complete. Avg Loss: 7.4627
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch70_target.wav
#
# Epoch 71/200
#   Batch 10/33 | Loss: 10.0541
#   Batch 20/33 | Loss: 5.3706
#   Batch 30/33 | Loss: 7.4749
#   Batch 33/33 | Loss: 10.4546
# Epoch 71 complete. Avg Loss: 7.6100
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch71_target.wav
#
# Epoch 72/200
#   Batch 10/33 | Loss: 6.7407
#   Batch 20/33 | Loss: 6.4396
#   Batch 30/33 | Loss: 7.3190
#   Batch 33/33 | Loss: 8.5181
# Epoch 72 complete. Avg Loss: 7.5593
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch72_target.wav
#
# Epoch 73/200
#   Batch 10/33 | Loss: 8.4116
#   Batch 20/33 | Loss: 4.5377
#   Batch 30/33 | Loss: 6.6947
#   Batch 33/33 | Loss: 4.4842
# Epoch 73 complete. Avg Loss: 7.4522
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch73_target.wav
#
# Epoch 74/200
#   Batch 10/33 | Loss: 6.2474
#   Batch 20/33 | Loss: 5.8955
#   Batch 30/33 | Loss: 7.2046
#   Batch 33/33 | Loss: 4.0861
# Epoch 74 complete. Avg Loss: 7.4436
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch74_target.wav
#
# Epoch 75/200
#   Batch 10/33 | Loss: 8.9121
#   Batch 20/33 | Loss: 10.4091
#   Batch 30/33 | Loss: 9.4651
#   Batch 33/33 | Loss: 10.9143
# Epoch 75 complete. Avg Loss: 7.6229
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch75_target.wav
#
# Epoch 76/200
#   Batch 10/33 | Loss: 3.8531
#   Batch 20/33 | Loss: 8.4121
#   Batch 30/33 | Loss: 8.3662
#   Batch 33/33 | Loss: 12.2056
# Epoch 76 complete. Avg Loss: 7.6565
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch76_target.wav
#
# Epoch 77/200
#   Batch 10/33 | Loss: 6.8208
#   Batch 20/33 | Loss: 7.0687
#   Batch 30/33 | Loss: 7.3116
#   Batch 33/33 | Loss: 2.9640
# Epoch 77 complete. Avg Loss: 7.4113
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch77_target.wav
#
# Epoch 78/200
#   Batch 10/33 | Loss: 6.2396
#   Batch 20/33 | Loss: 6.3331
#   Batch 30/33 | Loss: 11.0979
#   Batch 33/33 | Loss: 7.5511
# Epoch 78 complete. Avg Loss: 7.5337
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch78_target.wav
#
# Epoch 79/200
#   Batch 10/33 | Loss: 4.9629
#   Batch 20/33 | Loss: 6.5191
#   Batch 30/33 | Loss: 6.2575
#   Batch 33/33 | Loss: 15.8155
# Epoch 79 complete. Avg Loss: 7.7524
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch79_target.wav
#
# Epoch 80/200
#   Batch 10/33 | Loss: 10.0315
#   Batch 20/33 | Loss: 6.0054
#   Batch 30/33 | Loss: 9.7651
#   Batch 33/33 | Loss: 15.3256
# Epoch 80 complete. Avg Loss: 7.7393
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch80_target.wav
#
# Epoch 81/200
#   Batch 10/33 | Loss: 7.4697
#   Batch 20/33 | Loss: 5.7750
#   Batch 30/33 | Loss: 6.6974
#   Batch 33/33 | Loss: 10.6738
# Epoch 81 complete. Avg Loss: 7.6239
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch81_target.wav
#
# Epoch 82/200
#   Batch 10/33 | Loss: 8.8824
#   Batch 20/33 | Loss: 6.4057
#   Batch 30/33 | Loss: 6.5682
#   Batch 33/33 | Loss: 9.0595
# Epoch 82 complete. Avg Loss: 7.5731
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch82_target.wav
#
# Epoch 83/200
#   Batch 10/33 | Loss: 9.1883
#   Batch 20/33 | Loss: 6.6600
#   Batch 30/33 | Loss: 7.4040
#   Batch 33/33 | Loss: 4.6651
# Epoch 83 complete. Avg Loss: 7.4570
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch83_target.wav
#
# Epoch 84/200
#   Batch 10/33 | Loss: 7.1281
#   Batch 20/33 | Loss: 6.3457
#   Batch 30/33 | Loss: 6.0434
#   Batch 33/33 | Loss: 2.6167
# Epoch 84 complete. Avg Loss: 7.4039
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch84_target.wav
#
# Epoch 85/200
#   Batch 10/33 | Loss: 7.8210
#   Batch 20/33 | Loss: 6.6504
#   Batch 30/33 | Loss: 7.0076
#   Batch 33/33 | Loss: 12.8503
# Epoch 85 complete. Avg Loss: 7.6733
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch85_target.wav
#
# Epoch 86/200
#   Batch 10/33 | Loss: 7.7904
#   Batch 20/33 | Loss: 11.6342
#   Batch 30/33 | Loss: 8.9833
#   Batch 33/33 | Loss: 4.8497
# Epoch 86 complete. Avg Loss: 7.4620
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch86_target.wav
#
# Epoch 87/200
#   Batch 10/33 | Loss: 15.9126
#   Batch 20/33 | Loss: 8.1876
#   Batch 30/33 | Loss: 7.7617
#   Batch 33/33 | Loss: 3.7635
# Epoch 87 complete. Avg Loss: 7.4329
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch87_target.wav
#
# Epoch 88/200
#   Batch 10/33 | Loss: 10.0208
#   Batch 20/33 | Loss: 7.8137
#   Batch 30/33 | Loss: 12.2346
#   Batch 33/33 | Loss: 6.1055
# Epoch 88 complete. Avg Loss: 7.4952
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch88_target.wav
#
# Epoch 89/200
#   Batch 10/33 | Loss: 9.9626
#   Batch 20/33 | Loss: 4.7587
#   Batch 30/33 | Loss: 6.5448
#   Batch 33/33 | Loss: 5.3186
# Epoch 89 complete. Avg Loss: 7.4735
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch89_target.wav
#
# Epoch 90/200
#   Batch 10/33 | Loss: 10.8339
#   Batch 20/33 | Loss: 8.4564
#   Batch 30/33 | Loss: 7.1178
#   Batch 33/33 | Loss: 4.3507
# Epoch 90 complete. Avg Loss: 7.4480
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch90_target.wav
#
# Epoch 91/200
#   Batch 10/33 | Loss: 6.7136
#   Batch 20/33 | Loss: 5.9486
#   Batch 30/33 | Loss: 8.1087
#   Batch 33/33 | Loss: 9.5259
# Epoch 91 complete. Avg Loss: 7.5849
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch91_target.wav
#
# Epoch 92/200
#   Batch 10/33 | Loss: 9.4882
#   Batch 20/33 | Loss: 6.7270
#   Batch 30/33 | Loss: 7.4231
#   Batch 33/33 | Loss: 22.4872
# Epoch 92 complete. Avg Loss: 7.9290
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch92_target.wav
#
# Epoch 93/200
#   Batch 10/33 | Loss: 5.9348
#   Batch 20/33 | Loss: 6.1760
#   Batch 30/33 | Loss: 7.8426
#   Batch 33/33 | Loss: 10.8014
# Epoch 93 complete. Avg Loss: 7.6189
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch93_target.wav
#
# Epoch 94/200
#   Batch 10/33 | Loss: 4.7376
#   Batch 20/33 | Loss: 5.4334
#   Batch 30/33 | Loss: 10.6460
#   Batch 33/33 | Loss: 12.7569
# Epoch 94 complete. Avg Loss: 7.6711
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch94_target.wav
#
# Epoch 95/200
#   Batch 10/33 | Loss: 8.1793
#   Batch 20/33 | Loss: 6.4806
#   Batch 30/33 | Loss: 7.3431
#   Batch 33/33 | Loss: 3.8815
# Epoch 95 complete. Avg Loss: 7.4354
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch95_target.wav
#
# Epoch 96/200
#   Batch 10/33 | Loss: 10.6073
#   Batch 20/33 | Loss: 4.7612
#   Batch 30/33 | Loss: 8.7600
#   Batch 33/33 | Loss: 6.6011
# Epoch 96 complete. Avg Loss: 7.5084
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch96_target.wav
#
# Epoch 97/200
#   Batch 10/33 | Loss: 4.3201
#   Batch 20/33 | Loss: 10.6057
#   Batch 30/33 | Loss: 7.9556
#   Batch 33/33 | Loss: 7.4002
# Epoch 97 complete. Avg Loss: 7.5353
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch97_target.wav
#
# Epoch 98/200
#   Batch 10/33 | Loss: 6.8105
#   Batch 20/33 | Loss: 6.5858
#   Batch 30/33 | Loss: 6.9190
#   Batch 33/33 | Loss: 8.0670
# Epoch 98 complete. Avg Loss: 7.5464
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch98_target.wav
#
# Epoch 99/200
#   Batch 10/33 | Loss: 6.1515
#   Batch 20/33 | Loss: 4.8785
#   Batch 30/33 | Loss: 8.8026
#   Batch 33/33 | Loss: 4.3662
# Epoch 99 complete. Avg Loss: 7.4482
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch99_target.wav
#
# Epoch 100/200
#   Batch 10/33 | Loss: 5.0382
#   Batch 20/33 | Loss: 7.3278
#   Batch 30/33 | Loss: 5.3778
#   Batch 33/33 | Loss: 7.0385
# Epoch 100 complete. Avg Loss: 7.5189
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch100_target.wav
#
# Epoch 101/200
#   Batch 10/33 | Loss: 5.4015
#   Batch 20/33 | Loss: 6.9401
#   Batch 30/33 | Loss: 5.3519
#   Batch 33/33 | Loss: 7.9377
# Epoch 101 complete. Avg Loss: 7.5429
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch101_target.wav
#
# Epoch 102/200
#   Batch 10/33 | Loss: 11.1928
#   Batch 20/33 | Loss: 5.7583
#   Batch 30/33 | Loss: 6.6484
#   Batch 33/33 | Loss: 5.9777
# Epoch 102 complete. Avg Loss: 7.4906
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch102_target.wav
#
# Epoch 103/200
#   Batch 10/33 | Loss: 9.9212
#   Batch 20/33 | Loss: 6.4379
#   Batch 30/33 | Loss: 12.4764
#   Batch 33/33 | Loss: 12.3383
# Epoch 103 complete. Avg Loss: 7.6595
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch103_target.wav
#
# Epoch 104/200
#   Batch 10/33 | Loss: 6.8861
#   Batch 20/33 | Loss: 6.5928
#   Batch 30/33 | Loss: 7.4790
#   Batch 33/33 | Loss: 3.5767
# Epoch 104 complete. Avg Loss: 7.4271
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch104_target.wav
#
# Epoch 105/200
#   Batch 10/33 | Loss: 9.1924
#   Batch 20/33 | Loss: 6.1167
#   Batch 30/33 | Loss: 7.2420
#   Batch 33/33 | Loss: 1.5329
# Epoch 105 complete. Avg Loss: 7.3727
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch105_target.wav
#
# Epoch 106/200
#   Batch 10/33 | Loss: 7.9343
#   Batch 20/33 | Loss: 7.1791
#   Batch 30/33 | Loss: 7.4667
#   Batch 33/33 | Loss: 3.5699
# Epoch 106 complete. Avg Loss: 7.4292
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch106_target.wav
#
# Epoch 107/200
#   Batch 10/33 | Loss: 6.6099
#   Batch 20/33 | Loss: 7.2954
#   Batch 30/33 | Loss: 7.4477
#   Batch 33/33 | Loss: 3.0061
# Epoch 107 complete. Avg Loss: 7.4120
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch107_target.wav
#
# Epoch 108/200
#   Batch 10/33 | Loss: 7.7511
#   Batch 20/33 | Loss: 7.1668
#   Batch 30/33 | Loss: 7.0737
#   Batch 33/33 | Loss: 4.5307
# Epoch 108 complete. Avg Loss: 7.4521
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch108_target.wav
#
# Epoch 109/200
#   Batch 10/33 | Loss: 4.8543
#   Batch 20/33 | Loss: 6.7433
#   Batch 30/33 | Loss: 6.5654
#   Batch 33/33 | Loss: 13.3382
# Epoch 109 complete. Avg Loss: 7.6862
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch109_target.wav
#
# Epoch 110/200
#   Batch 10/33 | Loss: 8.4695
#   Batch 20/33 | Loss: 7.5613
#   Batch 30/33 | Loss: 4.6041
#   Batch 33/33 | Loss: 7.7558
# Epoch 110 complete. Avg Loss: 7.5377
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch110_target.wav
#
# Epoch 111/200
#   Batch 10/33 | Loss: 4.8155
#   Batch 20/33 | Loss: 7.1992
#   Batch 30/33 | Loss: 8.2185
#   Batch 33/33 | Loss: 11.2506
# Epoch 111 complete. Avg Loss: 7.6305
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch111_target.wav
#
# Epoch 112/200
#   Batch 10/33 | Loss: 10.5466
#   Batch 20/33 | Loss: 5.8533
#   Batch 30/33 | Loss: 13.3032
#   Batch 33/33 | Loss: 2.0061
# Epoch 112 complete. Avg Loss: 7.3864
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch112_target.wav
#
# Epoch 113/200
#   Batch 10/33 | Loss: 7.8653
#   Batch 20/33 | Loss: 11.2284
#   Batch 30/33 | Loss: 9.7784
#   Batch 33/33 | Loss: 4.7928
# Epoch 113 complete. Avg Loss: 7.4590
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch113_target.wav
#
# Epoch 114/200
#   Batch 10/33 | Loss: 6.9268
#   Batch 20/33 | Loss: 6.5454
#   Batch 30/33 | Loss: 11.1607
#   Batch 33/33 | Loss: 3.1110
# Epoch 114 complete. Avg Loss: 7.4144
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch114_target.wav
#
# Epoch 115/200
#   Batch 10/33 | Loss: 8.3992
#   Batch 20/33 | Loss: 6.8727
#   Batch 30/33 | Loss: 7.5298
#   Batch 33/33 | Loss: 10.5734
# Epoch 115 complete. Avg Loss: 7.6123
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch115_target.wav
#
# Epoch 116/200
#   Batch 10/33 | Loss: 5.7909
#   Batch 20/33 | Loss: 6.9273
#   Batch 30/33 | Loss: 6.7489
#   Batch 33/33 | Loss: 5.9148
# Epoch 116 complete. Avg Loss: 7.4893
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch116_target.wav
#
# Epoch 117/200
#   Batch 10/33 | Loss: 7.9169
#   Batch 20/33 | Loss: 7.2933
#   Batch 30/33 | Loss: 6.4130
#   Batch 33/33 | Loss: 6.2605
# Epoch 117 complete. Avg Loss: 7.4979
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch117_target.wav
#
# Epoch 118/200
#   Batch 10/33 | Loss: 7.2603
#   Batch 20/33 | Loss: 6.5877
#   Batch 30/33 | Loss: 6.8517
#   Batch 33/33 | Loss: 3.3929
# Epoch 118 complete. Avg Loss: 7.4225
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch118_target.wav
#
# Epoch 119/200
#   Batch 10/33 | Loss: 7.0563
#   Batch 20/33 | Loss: 16.5953
#   Batch 30/33 | Loss: 6.9615
#   Batch 33/33 | Loss: 21.9928
# Epoch 119 complete. Avg Loss: 7.9152
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch119_target.wav
#
# Epoch 120/200
#   Batch 10/33 | Loss: 7.0892
#   Batch 20/33 | Loss: 6.9885
#   Batch 30/33 | Loss: 4.7276
#   Batch 33/33 | Loss: 16.7760
# Epoch 120 complete. Avg Loss: 7.7769
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch120_target.wav
#
# Epoch 121/200
#   Batch 10/33 | Loss: 7.4009
#   Batch 20/33 | Loss: 7.2891
#   Batch 30/33 | Loss: 5.8183
#   Batch 33/33 | Loss: 5.2265
# Epoch 121 complete. Avg Loss: 7.4707
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch121_target.wav
#
# Epoch 122/200
#   Batch 10/33 | Loss: 12.2007
#   Batch 20/33 | Loss: 9.9020
#   Batch 30/33 | Loss: 8.7411
#   Batch 33/33 | Loss: 7.6491
# Epoch 122 complete. Avg Loss: 7.5346
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch122_target.wav
#
# Epoch 123/200
#   Batch 10/33 | Loss: 8.3815
#   Batch 20/33 | Loss: 4.5697
#   Batch 30/33 | Loss: 8.5185
#   Batch 33/33 | Loss: 6.5323
# Epoch 123 complete. Avg Loss: 7.5051
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch123_target.wav
#
# Epoch 124/200
#   Batch 10/33 | Loss: 6.0515
#   Batch 20/33 | Loss: 9.3675
#   Batch 30/33 | Loss: 5.3951
#   Batch 33/33 | Loss: 6.5203
# Epoch 124 complete. Avg Loss: 7.5046
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch124_target.wav
#
# Epoch 125/200
#   Batch 10/33 | Loss: 8.2236
#   Batch 20/33 | Loss: 6.8830
#   Batch 30/33 | Loss: 6.8286
#   Batch 33/33 | Loss: 16.0646
# Epoch 125 complete. Avg Loss: 7.7584
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch125_target.wav
#
# Epoch 126/200
#   Batch 10/33 | Loss: 8.8533
#   Batch 20/33 | Loss: 8.0281
#   Batch 30/33 | Loss: 6.3013
#   Batch 33/33 | Loss: 9.2645
# Epoch 126 complete. Avg Loss: 7.5858
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch126_target.wav
#
# Epoch 127/200
#   Batch 10/33 | Loss: 6.5266
#   Batch 20/33 | Loss: 8.4534
#   Batch 30/33 | Loss: 4.5770
#   Batch 33/33 | Loss: 4.7597
# Epoch 127 complete. Avg Loss: 7.4590
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch127_target.wav
#
# Epoch 128/200
#   Batch 10/33 | Loss: 8.4134
#   Batch 20/33 | Loss: 8.1797
#   Batch 30/33 | Loss: 6.5623
#   Batch 33/33 | Loss: 2.6992
# Epoch 128 complete. Avg Loss: 7.4066
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch128_target.wav
#
# Epoch 129/200
#   Batch 10/33 | Loss: 6.1813
#   Batch 20/33 | Loss: 5.9104
#   Batch 30/33 | Loss: 7.1345
#   Batch 33/33 | Loss: 9.1252
# Epoch 129 complete. Avg Loss: 7.5736
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch129_target.wav
#
# Epoch 130/200
#   Batch 10/33 | Loss: 7.7964
#   Batch 20/33 | Loss: 6.7238
#   Batch 30/33 | Loss: 7.5757
#   Batch 33/33 | Loss: 9.4506
# Epoch 130 complete. Avg Loss: 7.5828
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch130_target.wav
#
# Epoch 131/200
#   Batch 10/33 | Loss: 6.4066
#   Batch 20/33 | Loss: 5.9592
#   Batch 30/33 | Loss: 5.1272
#   Batch 33/33 | Loss: 6.3813
# Epoch 131 complete. Avg Loss: 7.5009
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch131_target.wav
#
# Epoch 132/200
#   Batch 10/33 | Loss: 4.0933
#   Batch 20/33 | Loss: 7.7105
#   Batch 30/33 | Loss: 8.1096
#   Batch 33/33 | Loss: 8.1621
# Epoch 132 complete. Avg Loss: 7.5483
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch132_target.wav
#
# Epoch 133/200
#   Batch 10/33 | Loss: 9.7721
#   Batch 20/33 | Loss: 8.2735
#   Batch 30/33 | Loss: 7.1992
#   Batch 33/33 | Loss: 25.3851
# Epoch 133 complete. Avg Loss: 8.0049
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch133_target.wav
#
# Epoch 134/200
#   Batch 10/33 | Loss: 5.2692
#   Batch 20/33 | Loss: 9.2454
#   Batch 30/33 | Loss: 13.5839
#   Batch 33/33 | Loss: 4.3711
# Epoch 134 complete. Avg Loss: 7.4482
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch134_target.wav
#
# Epoch 135/200
#   Batch 10/33 | Loss: 7.0817
#   Batch 20/33 | Loss: 7.3120
#   Batch 30/33 | Loss: 6.2072
#   Batch 33/33 | Loss: 1.8928
# Epoch 135 complete. Avg Loss: 7.3829
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch135_target.wav
#
# Epoch 136/200
#   Batch 10/33 | Loss: 5.7856
#   Batch 20/33 | Loss: 5.9438
#   Batch 30/33 | Loss: 15.1243
#   Batch 33/33 | Loss: 6.7630
# Epoch 136 complete. Avg Loss: 7.5112
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch136_target.wav
#
# Epoch 137/200
#   Batch 10/33 | Loss: 7.5364
#   Batch 20/33 | Loss: 7.7000
#   Batch 30/33 | Loss: 6.7504
#   Batch 33/33 | Loss: 11.7512
# Epoch 137 complete. Avg Loss: 7.6433
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch137_target.wav
#
# Epoch 138/200
#   Batch 10/33 | Loss: 6.4082
#   Batch 20/33 | Loss: 5.7264
#   Batch 30/33 | Loss: 5.3676
#   Batch 33/33 | Loss: 4.0254
# Epoch 138 complete. Avg Loss: 7.4384
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch138_target.wav
#
# Epoch 139/200
#   Batch 10/33 | Loss: 8.5165
#   Batch 20/33 | Loss: 9.9113
#   Batch 30/33 | Loss: 6.9667
#   Batch 33/33 | Loss: 7.0283
# Epoch 139 complete. Avg Loss: 7.5179
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch139_target.wav
#
# Epoch 140/200
#   Batch 10/33 | Loss: 7.3641
#   Batch 20/33 | Loss: 8.3648
#   Batch 30/33 | Loss: 7.4474
#   Batch 33/33 | Loss: 3.9181
# Epoch 140 complete. Avg Loss: 7.4362
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch140_target.wav
#
# Epoch 141/200
#   Batch 10/33 | Loss: 8.7911
#   Batch 20/33 | Loss: 12.7457
#   Batch 30/33 | Loss: 9.5710
#   Batch 33/33 | Loss: 6.2631
# Epoch 141 complete. Avg Loss: 7.4976
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch141_target.wav
#
# Epoch 142/200
#   Batch 10/33 | Loss: 6.6937
#   Batch 20/33 | Loss: 8.8798
#   Batch 30/33 | Loss: 11.7964
#   Batch 33/33 | Loss: 7.2366
# Epoch 142 complete. Avg Loss: 7.5232
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch142_target.wav
#
# Epoch 143/200
#   Batch 10/33 | Loss: 5.2129
#   Batch 20/33 | Loss: 6.8531
#   Batch 30/33 | Loss: 11.6206
#   Batch 33/33 | Loss: 2.6126
# Epoch 143 complete. Avg Loss: 7.4007
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch143_target.wav
#
# Epoch 144/200
#   Batch 10/33 | Loss: 9.0101
#   Batch 20/33 | Loss: 8.7959
#   Batch 30/33 | Loss: 5.8616
#   Batch 33/33 | Loss: 3.6301
# Epoch 144 complete. Avg Loss: 7.4277
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch144_target.wav
#
# Epoch 145/200
#   Batch 10/33 | Loss: 5.6886
#   Batch 20/33 | Loss: 9.3871
#   Batch 30/33 | Loss: 8.0061
#   Batch 33/33 | Loss: 9.1233
# Epoch 145 complete. Avg Loss: 7.5739
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch145_target.wav
#
# Epoch 146/200
#   Batch 10/33 | Loss: 8.7755
#   Batch 20/33 | Loss: 8.3719
#   Batch 30/33 | Loss: 8.1896
#   Batch 33/33 | Loss: 6.3348
# Epoch 146 complete. Avg Loss: 7.4994
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch146_target.wav
#
# Epoch 147/200
#   Batch 10/33 | Loss: 9.5345
#   Batch 20/33 | Loss: 6.5818
#   Batch 30/33 | Loss: 6.5951
#   Batch 33/33 | Loss: 3.8610
# Epoch 147 complete. Avg Loss: 7.4339
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch147_target.wav
#
# Epoch 148/200
#   Batch 10/33 | Loss: 8.1474
#   Batch 20/33 | Loss: 6.7309
#   Batch 30/33 | Loss: 7.0388
#   Batch 33/33 | Loss: 5.4297
# Epoch 148 complete. Avg Loss: 7.4756
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch148_target.wav
#
# Epoch 149/200
#   Batch 10/33 | Loss: 6.2254
#   Batch 20/33 | Loss: 6.9591
#   Batch 30/33 | Loss: 6.1629
#   Batch 33/33 | Loss: 6.2955
# Epoch 149 complete. Avg Loss: 7.4987
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch149_target.wav
#
# Epoch 150/200
#   Batch 10/33 | Loss: 11.5815
#   Batch 20/33 | Loss: 6.1126
#   Batch 30/33 | Loss: 7.1838
#   Batch 33/33 | Loss: 5.4422
# Epoch 150 complete. Avg Loss: 7.4768
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch150_target.wav
#
# Epoch 151/200
#   Batch 10/33 | Loss: 6.7554
#   Batch 20/33 | Loss: 7.1066
#   Batch 30/33 | Loss: 6.8709
#   Batch 33/33 | Loss: 6.2827
# Epoch 151 complete. Avg Loss: 7.4981
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch151_target.wav
#
# Epoch 152/200
#   Batch 10/33 | Loss: 5.9398
#   Batch 20/33 | Loss: 6.5887
#   Batch 30/33 | Loss: 6.9825
#   Batch 33/33 | Loss: 9.9952
# Epoch 152 complete. Avg Loss: 7.5964
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch152_target.wav
#
# Epoch 153/200
#   Batch 10/33 | Loss: 6.7204
#   Batch 20/33 | Loss: 9.5789
#   Batch 30/33 | Loss: 5.4214
#   Batch 33/33 | Loss: 4.4880
# Epoch 153 complete. Avg Loss: 7.4518
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch153_target.wav
#
# Epoch 154/200
#   Batch 10/33 | Loss: 7.2966
#   Batch 20/33 | Loss: 7.9692
#   Batch 30/33 | Loss: 5.9448
#   Batch 33/33 | Loss: 4.8602
# Epoch 154 complete. Avg Loss: 7.4610
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch154_target.wav
#
# Epoch 155/200
#   Batch 10/33 | Loss: 9.1388
#   Batch 20/33 | Loss: 7.4162
#   Batch 30/33 | Loss: 6.3504
#   Batch 33/33 | Loss: 8.8777
# Epoch 155 complete. Avg Loss: 7.5675
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch155_target.wav
#
# Epoch 156/200
#   Batch 10/33 | Loss: 7.3485
#   Batch 20/33 | Loss: 6.3333
#   Batch 30/33 | Loss: 5.4734
#   Batch 33/33 | Loss: 7.1751
# Epoch 156 complete. Avg Loss: 7.5216
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch156_target.wav
#
# Epoch 157/200
#   Batch 10/33 | Loss: 6.1970
#   Batch 20/33 | Loss: 9.1015
#   Batch 30/33 | Loss: 7.1125
#   Batch 33/33 | Loss: 5.1381
# Epoch 157 complete. Avg Loss: 7.4692
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch157_target.wav
#
# Epoch 158/200
#   Batch 10/33 | Loss: 5.4991
#   Batch 20/33 | Loss: 6.4139
#   Batch 30/33 | Loss: 4.7754
#   Batch 33/33 | Loss: 16.0609
# Epoch 158 complete. Avg Loss: 7.7572
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch158_target.wav
#
# Epoch 159/200
#   Batch 10/33 | Loss: 6.3915
#   Batch 20/33 | Loss: 6.9737
#   Batch 30/33 | Loss: 8.5202
#   Batch 33/33 | Loss: 6.0924
# Epoch 159 complete. Avg Loss: 7.4939
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch159_target.wav
#
# Epoch 160/200
#   Batch 10/33 | Loss: 8.0967
#   Batch 20/33 | Loss: 7.1760
#   Batch 30/33 | Loss: 5.0570
#   Batch 33/33 | Loss: 1.9920
# Epoch 160 complete. Avg Loss: 7.3844
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch160_target.wav
#
# Epoch 161/200
#   Batch 10/33 | Loss: 6.3431
#   Batch 20/33 | Loss: 9.1414
#   Batch 30/33 | Loss: 6.0437
#   Batch 33/33 | Loss: 11.0492
# Epoch 161 complete. Avg Loss: 7.6244
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch161_target.wav
#
# Epoch 162/200
#   Batch 10/33 | Loss: 8.4020
#   Batch 20/33 | Loss: 7.1261
#   Batch 30/33 | Loss: 6.9857
#   Batch 33/33 | Loss: 4.8725
# Epoch 162 complete. Avg Loss: 7.4616
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch162_target.wav
#
# Epoch 163/200
#   Batch 10/33 | Loss: 7.5885
#   Batch 20/33 | Loss: 8.0133
#   Batch 30/33 | Loss: 5.3243
#   Batch 33/33 | Loss: 10.1509
# Epoch 163 complete. Avg Loss: 7.6021
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch163_target.wav
#
# Epoch 164/200
#   Batch 10/33 | Loss: 6.1494
#   Batch 20/33 | Loss: 5.1431
#   Batch 30/33 | Loss: 13.9707
#   Batch 33/33 | Loss: 4.6454
# Epoch 164 complete. Avg Loss: 7.4552
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch164_target.wav
#
# Epoch 165/200
#   Batch 10/33 | Loss: 7.7875
#   Batch 20/33 | Loss: 7.6530
#   Batch 30/33 | Loss: 7.0814
#   Batch 33/33 | Loss: 4.8832
# Epoch 165 complete. Avg Loss: 7.4611
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch165_target.wav
#
# Epoch 166/200
#   Batch 10/33 | Loss: 8.7404
#   Batch 20/33 | Loss: 4.8181
#   Batch 30/33 | Loss: 5.2425
#   Batch 33/33 | Loss: 3.4130
# Epoch 166 complete. Avg Loss: 7.4217
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch166_target.wav
#
# Epoch 167/200
#   Batch 10/33 | Loss: 6.0819
#   Batch 20/33 | Loss: 4.8538
#   Batch 30/33 | Loss: 5.5040
#   Batch 33/33 | Loss: 9.6641
# Epoch 167 complete. Avg Loss: 7.5880
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch167_target.wav
#
# Epoch 168/200
#   Batch 10/33 | Loss: 7.2138
#   Batch 20/33 | Loss: 8.3968
#   Batch 30/33 | Loss: 6.8021
#   Batch 33/33 | Loss: 4.3061
# Epoch 168 complete. Avg Loss: 7.4458
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch168_target.wav
#
# Epoch 169/200
#   Batch 10/33 | Loss: 7.8276
#   Batch 20/33 | Loss: 6.1890
#   Batch 30/33 | Loss: 6.4717
#   Batch 33/33 | Loss: 7.9111
# Epoch 169 complete. Avg Loss: 7.5412
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch169_target.wav
#
# Epoch 170/200
#   Batch 10/33 | Loss: 11.5062
#   Batch 20/33 | Loss: 7.7114
#   Batch 30/33 | Loss: 12.0281
#   Batch 33/33 | Loss: 14.1338
# Epoch 170 complete. Avg Loss: 7.7061
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch170_target.wav
#
# Epoch 171/200
#   Batch 10/33 | Loss: 10.2734
#   Batch 20/33 | Loss: 5.4848
#   Batch 30/33 | Loss: 4.4522
#   Batch 33/33 | Loss: 4.8915
# Epoch 171 complete. Avg Loss: 7.4617
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch171_target.wav
#
# Epoch 172/200
#   Batch 10/33 | Loss: 8.4431
#   Batch 20/33 | Loss: 6.2708
#   Batch 30/33 | Loss: 7.5968
#   Batch 33/33 | Loss: 59.0873
# Epoch 172 complete. Avg Loss: 8.8981
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch172_target.wav
#
# Epoch 173/200
#   Batch 10/33 | Loss: 9.7126
#   Batch 20/33 | Loss: 5.4368
#   Batch 30/33 | Loss: 9.9641
#   Batch 33/33 | Loss: 6.3260
# Epoch 173 complete. Avg Loss: 7.5038
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch173_target.wav
#
# Epoch 174/200
#   Batch 10/33 | Loss: 8.4036
#   Batch 20/33 | Loss: 13.7360
#   Batch 30/33 | Loss: 6.4603
#   Batch 33/33 | Loss: 10.2420
# Epoch 174 complete. Avg Loss: 7.6035
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch174_target.wav
#
# Epoch 175/200
#   Batch 10/33 | Loss: 6.9601
#   Batch 20/33 | Loss: 5.4519
#   Batch 30/33 | Loss: 5.3840
#   Batch 33/33 | Loss: 2.2375
# Epoch 175 complete. Avg Loss: 7.3904
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch175_target.wav
#
# Epoch 176/200
#   Batch 10/33 | Loss: 6.0104
#   Batch 20/33 | Loss: 5.1616
#   Batch 30/33 | Loss: 7.9845
#   Batch 33/33 | Loss: 6.6720
# Epoch 176 complete. Avg Loss: 7.5081
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch176_target.wav
#
# Epoch 177/200
#   Batch 10/33 | Loss: 6.4297
#   Batch 20/33 | Loss: 6.5680
#   Batch 30/33 | Loss: 5.7438
#   Batch 33/33 | Loss: 5.6985
# Epoch 177 complete. Avg Loss: 7.4824
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch177_target.wav
#
# Epoch 178/200
#   Batch 10/33 | Loss: 6.2980
#   Batch 20/33 | Loss: 11.5427
#   Batch 30/33 | Loss: 5.7797
#   Batch 33/33 | Loss: 3.7187
# Epoch 178 complete. Avg Loss: 7.4298
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch178_target.wav
#
# Epoch 179/200
#   Batch 10/33 | Loss: 6.3673
#   Batch 20/33 | Loss: 6.9436
#   Batch 30/33 | Loss: 8.4863
#   Batch 33/33 | Loss: 4.5525
# Epoch 179 complete. Avg Loss: 7.4519
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch179_target.wav
#
# Epoch 180/200
#   Batch 10/33 | Loss: 6.0144
#   Batch 20/33 | Loss: 6.1517
#   Batch 30/33 | Loss: 7.8647
#   Batch 33/33 | Loss: 6.7186
# Epoch 180 complete. Avg Loss: 7.5093
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch180_target.wav
#
# Epoch 181/200
#   Batch 10/33 | Loss: 9.0837
#   Batch 20/33 | Loss: 14.8952
#   Batch 30/33 | Loss: 4.8156
#   Batch 33/33 | Loss: 11.0607
# Epoch 181 complete. Avg Loss: 7.6244
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch181_target.wav
#
# Epoch 182/200
#   Batch 10/33 | Loss: 6.0524
#   Batch 20/33 | Loss: 8.7567
#   Batch 30/33 | Loss: 5.4062
#   Batch 33/33 | Loss: 2.8746
# Epoch 182 complete. Avg Loss: 7.4073
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch182_target.wav
#
# Epoch 183/200
#   Batch 10/33 | Loss: 5.8200
#   Batch 20/33 | Loss: 8.5869
#   Batch 30/33 | Loss: 7.8685
#   Batch 33/33 | Loss: 7.5925
# Epoch 183 complete. Avg Loss: 7.5332
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch183_target.wav
#
# Epoch 184/200
#   Batch 10/33 | Loss: 5.6855
#   Batch 20/33 | Loss: 6.4925
#   Batch 30/33 | Loss: 9.5460
#   Batch 33/33 | Loss: 2.6075
# Epoch 184 complete. Avg Loss: 7.4005
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch184_target.wav
#
# Epoch 185/200
#   Batch 10/33 | Loss: 7.6641
#   Batch 20/33 | Loss: 7.2995
#   Batch 30/33 | Loss: 10.5183
#   Batch 33/33 | Loss: 24.6179
# Epoch 185 complete. Avg Loss: 7.9840
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch185_target.wav
#
# Epoch 186/200
#   Batch 10/33 | Loss: 8.6335
#   Batch 20/33 | Loss: 6.9980
#   Batch 30/33 | Loss: 9.2454
#   Batch 33/33 | Loss: 5.1182
# Epoch 186 complete. Avg Loss: 7.4673
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch186_target.wav
#
# Epoch 187/200
#   Batch 10/33 | Loss: 7.0595
#   Batch 20/33 | Loss: 8.0854
#   Batch 30/33 | Loss: 6.7555
#   Batch 33/33 | Loss: 3.5939
# Epoch 187 complete. Avg Loss: 7.4304
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch187_target.wav
#
# Epoch 188/200
#   Batch 10/33 | Loss: 8.0525
#   Batch 20/33 | Loss: 5.3967
#   Batch 30/33 | Loss: 7.3618
#   Batch 33/33 | Loss: 4.7438
# Epoch 188 complete. Avg Loss: 7.4577
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch188_target.wav
#
# Epoch 189/200
#   Batch 10/33 | Loss: 7.1819
#   Batch 20/33 | Loss: 9.2092
#   Batch 30/33 | Loss: 8.8709
#   Batch 33/33 | Loss: 5.6493
# Epoch 189 complete. Avg Loss: 7.4835
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch189_target.wav
#
# Epoch 190/200
#   Batch 10/33 | Loss: 16.2092
#   Batch 20/33 | Loss: 5.9541
#   Batch 30/33 | Loss: 6.7812
#   Batch 33/33 | Loss: 4.4249
# Epoch 190 complete. Avg Loss: 7.4487
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch190_target.wav
#
# Epoch 191/200
#   Batch 10/33 | Loss: 9.0145
#   Batch 20/33 | Loss: 7.5433
#   Batch 30/33 | Loss: 6.0009
#   Batch 33/33 | Loss: 3.3307
# Epoch 191 complete. Avg Loss: 7.4196
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch191_target.wav
#
# Epoch 192/200
#   Batch 10/33 | Loss: 7.8409
#   Batch 20/33 | Loss: 6.9023
#   Batch 30/33 | Loss: 6.7698
#   Batch 33/33 | Loss: 1.7554
# Epoch 192 complete. Avg Loss: 7.3775
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch192_target.wav
#
# Epoch 193/200
#   Batch 10/33 | Loss: 5.8358
#   Batch 20/33 | Loss: 8.0891
#   Batch 30/33 | Loss: 6.1025
#   Batch 33/33 | Loss: 8.8250
# Epoch 193 complete. Avg Loss: 7.5651
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch193_target.wav
#
# Epoch 194/200
#   Batch 10/33 | Loss: 7.2940
#   Batch 20/33 | Loss: 7.9409
#   Batch 30/33 | Loss: 8.5788
#   Batch 33/33 | Loss: 6.8026
# Epoch 194 complete. Avg Loss: 7.5117
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch194_target.wav
#
# Epoch 195/200
#   Batch 10/33 | Loss: 8.0281
#   Batch 20/33 | Loss: 8.2877
#   Batch 30/33 | Loss: 5.7178
#   Batch 33/33 | Loss: 9.9484
# Epoch 195 complete. Avg Loss: 7.5949
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch195_target.wav
#
# Epoch 196/200
#   Batch 10/33 | Loss: 6.3640
#   Batch 20/33 | Loss: 7.5383
#   Batch 30/33 | Loss: 7.7266
#   Batch 33/33 | Loss: 5.4723
# Epoch 196 complete. Avg Loss: 7.4817
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch196_target.wav
#
# Epoch 197/200
#   Batch 10/33 | Loss: 5.7971
#   Batch 20/33 | Loss: 6.3206
#   Batch 30/33 | Loss: 7.0420
#   Batch 33/33 | Loss: 4.8898
# Epoch 197 complete. Avg Loss: 7.4609
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch197_target.wav
#
# Epoch 198/200
#   Batch 10/33 | Loss: 7.2194
#   Batch 20/33 | Loss: 6.2249
#   Batch 30/33 | Loss: 9.1278
#   Batch 33/33 | Loss: 2.1507
# Epoch 198 complete. Avg Loss: 7.3891
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch198_target.wav
#
# Epoch 199/200
#   Batch 10/33 | Loss: 7.2556
#   Batch 20/33 | Loss: 6.1740
#   Batch 30/33 | Loss: 11.1672
#   Batch 33/33 | Loss: 8.1967
# Epoch 199 complete. Avg Loss: 7.5609
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch199_target.wav
#
# Epoch 200/200
#   Batch 10/33 | Loss: 6.8119
#   Batch 20/33 | Loss: 5.6173
#   Batch 30/33 | Loss: 7.3960
#   Batch 33/33 | Loss: 3.1211
# Epoch 200 complete. Avg Loss: 7.4143
# Saved target audio sample to /content/drive/MyDrive/generated_wavs/epoch200_target.wav
# Saved model to /content/drive/MyDrive/generated_wavs/model.pth

# %% [markdown]
# ## Model 1 Text input

# %%
#text in put code
phrase = "yellow black yellow black"
phrase_tokenized = tokenizer.encode(phrase)
phrase_tokenized = torch.tensor(phrase_tokenized).unsqueeze(0)
phrase_tensor = phrase_tokenized.to(device)

#bert model
with torch.no_grad():
    bert_outputs = bert_model(phrase_tensor)
    embeddings = bert_outputs.last_hidden_state
    embedded_input = embeddings.permute(0, 2, 1)

x = embeddings.permute(0, 2, 1)

#load model from .pth file
model_path = "/content/drive/MyDrive/generated_wavs/model.pth"
cnn.load_state_dict(torch.load(model_path))
cnn.eval()
model = cnn.to(device)

output_save_dir = "/content/drive/MyDrive/specific_phrases"
os.makedirs(output_save_dir, exist_ok=True)

#reconstruct waveform
output = model(embedded_input).permute(0, 2, 1)
save_path = os.path.join(output_save_dir, f"{phrase}.wav")
waveform = mel_to_audio(spec)
waveform = waveform / waveform.abs().max()
torchaudio.save(save_path, waveform.unsqueeze(0), sample_rate=40000)

# %% [markdown]
# # Model 2: Variational Auto-Encoder

# %% [markdown]
# Based on https://arxiv.org/pdf/2107.03298

# %% [markdown]
# ## Text Encoder
# Convolution layers with dropout, batch normalization and ReLU activation. Follow this with positional encoding, and then self attention blocks.

# %% [markdown]
# ## Model Evaluation

# %%
def sinosoidal_position_encoding(token_size, embedding_dim):
  pos = torch.arange(0, token_size).unsqueeze(1)
  emb = torch.zeros(token_size, embedding_dim)

  emb[:, 0::2] = torch.sin(pos/torch.pow(10000, 2*torch.arange(0, embedding_dim//2)/embedding_dim))
  emb[:, 1::2] = torch.cos(pos/torch.pow(10000, 2*torch.arange(0, embedding_dim//2)/embedding_dim))

  return emb



class ConvStack(torch.nn.Module):
  def __init__(self, D, K):
    super(ConvStack, self).__init__()
    self.conv = torch.nn.Conv1d(D, D, K)
    self.norm = torch.nn.BatchNorm1d(D)
    self.relu = torch.nn.ReLU()
    self.dropout = torch.nn.Dropout1d()
  def forward(self, X):
    convolution = self.conv(X)
    normalization = self.norm(convolution)
    relu = self.relu(normalization)
    output = self.dropout(relu)
    return output

class TextEncoder(torch.nn.Module):
  def __init__(self, embedding_size, conv_size, K):
    self.embedding = torch.nn.Embedding(embedding_size, conv_size)
    self.stack1 = ConvStack(conv_size, K)
    self.stack2 = ConvStack(conv_size, K)
    self.stack3 = ConvStack(conv_size, K)
    self.stack4 = ConvStack(conv_size, K)
    self.stack5 = ConvStack(conv_size, K)
    self.attention1 = torch.nn.MultiheadAttention(embedding_size, 4)
    self.attention2 = torch.nn.MultiheadAttention(embedding_size, 4)
    self.attention3 = torch.nn.MultiheadAttention(embedding_size, 4)
    self.attention4 = torch.nn.MultiheadAttention(embedding_size, 4)

  def forward(self, X):
    embed = self.embedding(X)
    conv1 = self.stack1(embed)
    conv2 = self.stack2(conv1)
    conv3 = self.stack3(conv1)
    conv4 = self.stack4(conv1)
    conv5 = self.stack5(conv1)
    conv_pos = conv5 + sinosoidal_position_encoding(X.size(0), 512)
    attn1 = self.attention1(conv_pos)
    attn2 = self.attention2(attn1)
    attn3 = self.attention3(attn2)
    attn4 = self.attention4(attn3)

    return attn4
